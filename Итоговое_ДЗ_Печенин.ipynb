# %%
cd C:\Users\Dev\Desktop\Netology\Big data\Итоговое ДЗ
# Out:
# C:\Users\Dev\Desktop\Netology\Big data\Итоговое ДЗ

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pymysql

# %%
df_csv = pd.read_csv('russia.index.cpi (statbureau.org).csv')
df_csv = df_csv[df_csv['Год'] > 2017].reset_index()
del df_csv ['index']
df_csv['inflation'] = (df_csv.iloc[:, 1:].mean(axis=1).round(2)) - 100
df_csv
df_xlsx = pd.read_excel('RC_F30_11_2018_T30_11_2023.xlsx')
df_xlsx['data'] = pd.to_datetime(df_xlsx['data'])
df_xlsx['year_month'] = df_xlsx['data'].dt.to_period('M')
df_xlsx = df_xlsx.groupby('year_month').agg({'curs': 'mean'}).reset_index()
df_xlsx.head(10)
# Out:
#     Год   Январь   Февраль    Март   Апрель     Май    Июнь    Июль   Август  \
# 0  2018   100.31    100.21  100.29   100.38  100.38  100.49  100.27   100.01
# 1  2019   101.01    100.44  100.32   100.29  100.34  100.04  100.20    99.76
# 2  2020   100.40    100.33  100.55   100.83  100.27  100.22  100.35    99.96
# 3  2021   100.67    100.78  100.66   100.58  100.74  100.69  100.31   100.17
# 4  2022   100.99    101.17  107.61   101.56  100.12   99.65   99.61    99.48
# 5  2023   100.84    100.46  100.37   100.38  100.31  100.37  100.63   100.28
#
#     Сентябрь   Октябрь   Ноябрь   Декабрь  inflation
# 0     100.16    100.35   100.50    100.84       0.35
# 1      99.84    100.13   100.28    100.36       0.25
# 2      99.93    100.43   100.71    100.83       0.40
# 3     100.60    101.11   100.96    100.82       0.67
# 4     100.05    100.18   100.37    100.78       0.96
# 5     100.87    100.83      NaN       NaN       0.53

# %%
#Строим графики динамики курса рубля

# %%
df_xlsx['year_month'] = df_xlsx['year_month'].dt.to_timestamp()
plt.plot(df_xlsx['year_month'], df_xlsx['curs'])
plt.show()

# %%
plt.plot(df_xlsx['year_month'], df_xlsx['curs'])
plt.show()

# %%
#Строю график инфляции

# %%
plt.plot(df_csv['Год'], df_csv['inflation'])
plt.show()
